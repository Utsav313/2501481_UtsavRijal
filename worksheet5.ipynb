# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/content/student.csv")
print(data.head())
print(data.tail())
print(data.info())
print(data.describe())
X = data[["Math", "Reading"]].values
Y = data["Writing"].values
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62
#      Math  Reading  Writing
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB
# None
#               Math      Reading      Writing
# count  1000.000000  1000.000000  1000.000000
# mean     67.290000    69.872000    68.616000
# std      15.085008    14.657027    15.241287
# min      13.000000    19.000000    14.000000
# 25%      58.000000    60.750000    58.000000
# ...

# %% [markdown]
# To do-3

# %%
def split_data(X, Y, test_size=0.2, random_state=42):
        return train_test_split(X, Y, test_size=test_size, random_state=random_state)

# %% [markdown]
# To do-4

# %%
def cost_function(X, Y, W):
 n = len(Y)
 Y_pred = np.dot(X, W)
 cost = (1 / (2 * n)) * np.sum((Y_pred - Y) ** 2)
 return cost

# %% [markdown]
# To do-5

# %%
X_test = np.array([[1, 2], [3, 4], [5, 6]])
Y_test = np.array([3, 7, 11])
W_test = np.array([1, 1])


print("\nCost Function Test Output:", cost_function(X_test, Y_test, W_test))
# Out:
# Cost Function Test Output: 0.0

# %% [markdown]
# TO do-6

# %%
def gradient_descent(X, Y, W, alpha, iterations):

    cost_history = [0] * iterations
    m = len(Y)
    W_update = W.copy()

    for iteration in range(iterations):

        Y_pred = np.dot(X, W_update)
        loss = Y_pred - Y
        dw = (1 / m) * np.dot(X.T, loss)
        W_update = W_update - alpha * dw
        cost = cost_function(X, Y, W_update)
        cost_history[iteration] = cost

    return W_update, cost_history

# %% [markdown]
# To do-7

# %%
np.random.seed(0)
X_gd_test = np.random.rand(100, 3)
Y_gd_test = np.random.rand(100)
W_gd_test = np.random.rand(3)

alpha_test = 0.01
iterations_test = 1000

final_params, cost_history_test = gradient_descent(
    X_gd_test, Y_gd_test, W_gd_test, alpha_test, iterations_test
)

print(f"\nFinal Parameters: {final_params}")
print(f"Initial Cost: {cost_history_test[0]:.6f}")
print(f"Final Cost: {cost_history_test[-1]:.6f}")
# Out:
# Final Parameters: [0.20551667 0.54295081 0.10388027]
# Initial Cost: 0.107112
# Final Cost: 0.054355

# %% [markdown]
# To do-8

# %%
def rmse(Y, Y_pred):
  n = len(Y)
  rmse = np.sqrt((1 / n) * np.sum((Y - Y_pred) ** 2))
  return rmse

# %% [markdown]
# To do-9

# %%
def r2(Y, Y_pred):
  mean_y = np.mean(Y)
  ss_tot = np.sum((Y - mean_y) ** 2)
  ss_res = np.sum((Y - Y_pred) ** 2)
  return 1 - (ss_res / ss_tot)

# %% [markdown]
# To do-10

# %%
def main():
 X, Y = load_and_explore_data("student.csv")


# Train-Test Split
 X_train, X_test, Y_train, Y_test = split_data(X, Y)


# Initialize Parameters
 W = np.zeros(X_train.shape[1])
 alpha = 0.00001
 iterations = 1000


# Train Model
 W_optimal, cost_history = gradient_descent(X_train, Y_train, W, alpha, iterations)


# Predictions
 Y_pred = np.dot(X_test, W_optimal)
 model_rmse = rmse(Y_test, Y_pred)
 model_r2 = r2(Y_test, Y_pred)


# Output
 print("\n--- Model Results ---")
 print("Final Weights:", W_optimal)
 print("Cost History (First 10):", cost_history[:10])
 print("RMSE:", model_rmse)
 print("R2 Score:", model_r2)

 plt.figure()
 plt.plot(cost_history)
 plt.xlabel("Iterations")
 plt.ylabel("Cost (MSE)")
 plt.title("Training Loss Curve")
 plt.show()

 if __name__ == "__main__":
 main()
# Out:
#   File "/tmp/ipython-input-557336747.py", line 3
#     X, Y = load_and_explore_data("student.csv")
#     ^
# IndentationError: expected an indented block after function definition on line 1
